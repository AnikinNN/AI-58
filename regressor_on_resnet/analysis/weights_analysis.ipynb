# %%
import os
import sys

sys.path.append('/app/scripts/anikin/AI-58/')

from matplotlib import pyplot as plt

from regressor_on_resnet.pretrained_loader import PretrainedLoader
from regressor_on_resnet.weighted_mse import get_weights_and_bounds

plt.rcParams['figure.dpi'] = 150

# %%
pretrained_loader = PretrainedLoader()
dataset_path = '/app/scripts/anikin/AI-58/regressor_on_resnet/logs/misc_20220518_104201_92'
pretrained_loader.load_dataset(dataset_path)

# %%
for i in ('train', 'validation', 'test'):
    weights, bounds = get_weights_and_bounds(pretrained_loader.__getattribute__(i)['CM3up[W/m2]'].to_numpy())
    plt.plot(bounds, weights[:-1], '.-', label=i)
plt.xlabel('left bound of interval')
plt.ylabel('weight')
plt.legend()

# %%
plt.plot(bounds, '.-')
